# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

if __name__ == '__main__':
    pic = imageio.imread('query.JPEG')
    plt.figure(figsize = (10,10))
    plt.imshow(pic)

# %%
print('Type of the image : ' , type(pic))
print()
print('Shape of the image : {}'.format(pic.shape))
print('Image Hight {}'.format(pic.shape[0]))
print('Image Width {}'.format(pic.shape[1]))
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
#
# Shape of the image : (3174, 2205, 3)
# Image Hight 3174
# Image Width 2205
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size))
print('Maximum RGB value in this image {}'.format(pic.max()))
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 20996010
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
pic[ 100, 50 ]
# Out:
# Array([199, 181, 171], dtype=uint8)

# %%
plt.title('R channel')
plt.ylabel('Height {}'.format(pic.shape[0]))
plt.xlabel('Width {}'.format(pic.shape[1]))

plt.imshow(pic[ : , : , 0])
plt.show()

# %%
pic = imageio.imread('query.JPEG')

pic[1500:1750 , : , 2] = 255 # full intensity to those pixel's R channel
plt.figure( figsize = (10,10))
plt.imshow(pic)
plt.show()

# %%
pic[ 1600:2100 , 1600:1800 , [0,1,2] ] = 100 
plt.figure( figsize = (10,10))
plt.imshow(pic)
plt.show()

# %%
if __name__ == '__main__':
    
    # load the image
    pic = imageio.imread('query.JPEG')
    
    # seperate the row and column values
    total_row , total_col , layers = pic.shape
    
    '''
    Create vector.
    
    Ogrid is a compact method of creating a multidimensional-
    ndarray operations in single lines.
    for ex:
    
    >>> ogrid[0:5,0:5]
    output: [array([[0],
                    [1],
                    [2],
                    [3],
                    [4]]), 
            array([[0, 1, 2, 3, 4]])]
            
    '''
    x , y = np.ogrid[:total_row , :total_col]

    # get the center values of the image
    cen_x , cen_y = total_row/2 , total_col/2
    
    
    '''
    Measure distance value from center to each border pixel.
    To make it easy, we can think it's like, we draw a line from center-
    to each edge pixel value --> s**2 = (Y-y)**2 + (X-x)**2 
    '''
    distance_from_the_center = np.sqrt((x-cen_x)**2 + (y-cen_y)**2)

    # Select convenient radius value
    radius = (total_row/2)

    # Using logical operator '>' 
    '''
    logical operator to do this task which will return as a value 
    of True for all the index according to the given condition
    '''
    circular_pic = distance_from_the_center > radius

    '''
    let assign value zero for all pixel value that outside the cirular disc.
    All the pixel value outside the circular disc, will be black now.
    '''
    pic[circular_pic] = 0
    plt.figure(figsize = (10,10))
    plt.imshow(pic) 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cb929b950011> in <module>
#      23
#      24     '''
# ---> 25     x , y = np.ogrid[:total_row , :total_col]
#      26
#      27     # get the center values of the image
#
# NameError: name 'np' is not defined

# %%
# randomly choose a value 
low_pixel = pic < 20

# to ensure of it let's check if all values in low_pixel are True or not
if low_pixel.any() == True:
    print(low_pixel.shape)


import random

# load the orginal image
pic = imageio.imread('query.JPEG')

# set value randomly range from 25 to 225 - these value also randomly choosen
pic[low_pixel] = random.randint(25,225)

# display the image
plt.figure( figsize = (10,10))
plt.imshow(pic)
plt.show()
# Out:
# (3174, 2205, 3)

# %%
import random

# load the orginal image
pic = imageio.imread('query.JPEG')

# set value randomly range from 25 to 225 - these value also randomly choosen
pic[low_pixel] = random.randint(25,225)

# display the image
plt.figure( figsize = (10,10))
plt.imshow(pic)
plt.show()

# %%
# Only Red Pixel value , higher than 180
pic = imageio.imread('query.JPEG')
red_mask = pic[:, :, 0] < 180

pic[red_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(pic)


# Only Green Pixel value , higher than 180
pic = imageio.imread('query.JPEG')
green_mask = pic[:, :, 1] < 180

pic[green_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(pic)


# Only Blue Pixel value , higher than 180
pic = imageio.imread('query.JPEG')
blue_mask = pic[:, :, 2] < 180

pic[blue_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(pic)

# Composite mask using logical_and
pic = imageio.imread('query.JPEG')
final_mask = np.logical_and(red_mask, green_mask, blue_mask)
pic[final_mask] = 40
plt.figure(figsize=(15,15))
plt.imshow(pic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5066d1c010b3> in <module>
#      27 # Composite mask using logical_and
#      28 pic = imageio.imread('query.JPEG')
# ---> 29 final_mask = np.logical_and(red_mask, green_mask, blue_mask)
#      30 pic[final_mask] = 40
#      31 plt.figure(figsize=(15,15))
#
# NameError: name 'np' is not defined
